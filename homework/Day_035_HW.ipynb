# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾

# %% [markdown]
#  [Google News](https://news.google.com/topics/CAAqKggKIiRDQkFTRlFvSUwyMHZNRGRqTVhZU0JXVnVMVWxPR2dKSlRpZ0FQAQ/sections/CAQiRkNCQVNMZ29JTDIwdk1EZGpNWFlTQW1WdUdnSkpUaUlPQ0FRYUNnb0lMMjB2TUROeWJIUXFDaElJTDIwdk1ETnliSFFvQUEqKggAKiYICiIgQ0JBU0Vnb0lMMjB2TURkak1YWVNBbVZ1R2dKSlRpZ0FQAVAB?hl=en-IN&gl=IN&ceid=IN%3Aen)
# is another example of multi-label project.
#
# News can be classified into different categories.
#
# e.g. [Google Fiber is shutting down its super-high speed internet service in Louisville after residents complained that it left exposed cables in the streets](https://news.google...._YW1wX2pzX3Y9MC4xI3dlYnZpZXc9MSZjYXA9c3dpcGU?hl=en-IN&gl=IN&ceid=IN%3Aen), the news can be put into the tech category and the internet/network category

# %%
from IPython.display import Image
Image(filename='./pic/pic0351.png')
