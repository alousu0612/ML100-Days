# %% [markdown]
# # 作業:
#     請嘗試改用CIFAR100

# %% [markdown]
# # Import Library

# %%
import numpy
from keras.datasets import cifar100
import numpy as np
np.random.seed(100)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 資料準備

# %%
(x_img_train,y_label_train), \
(x_img_test, y_label_test)=cifar100.load_data()

# %%
x_img_train.shape, y_label_train.shape, x_img_test.shape, y_label_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
import matplotlib.pyplot as plt

def plot_images(images, labels, idx, prediction=None, num=10):
    
    fig = plt.gcf()
    fig.set_size_inches(12, 14)
    
    if num > 25:
        num = 25
    
    for i in range(idx, idx+num):
        ax = plt.subplot(5, 5, 1 + i)
        ax.imshow(images[i], cmap = plt.cm.binary)
        
        title = f'idx= {i}, label= {labels[i][0]}'
        if prediction is not None:
            title += f'=> {prediction[i]}'
            
        ax.set_title(title, fontsize=10)
        ax.set_xticks([])
        ax.set_yticks([])
    plt.show()

# %%
plot_images(x_img_train, y_label_train, 10)

# %% [markdown]
# # Image normalize

# %%
x_img_train_normalized = x_img_train.astype('float32') / 255.0
x_img_test_normalized = x_img_test.astype('float32') / 255.0

# %% [markdown]
# # 轉換label 為OneHot Encoding

# %%
y_label_train[:5]
# Out:
# array([[19],
#        [29],
#        [ 0],
#        [11],
#        [ 1]])

# %%
from keras.utils import np_utils 
y_label_train_onehot = np_utils.to_categorical(y_label_train)
y_label_test_onehot = np_utils.to_categorical(y_label_test)

# %%
y_label_train_onehot.shape
# Out:
# (50000, 100)
