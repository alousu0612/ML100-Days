# %% [markdown]
# # ML_Day001

# %% [markdown]
# ### * HW1

# %% [markdown]
# The data I choose is a dataset for Crowds Cure Cancer.(https://www.kaggle.com/kmader/crowds-cure-cancer-2017)

# %% [markdown]
# 1. This dataset is very useful for we find patterns of cancers by machine learning or deep learning. The research will benefit as in the future that the location of the tumors can be identified by machines.
#
# 2. The original dataset was downloaded from https://wiki.cancerimagingarchive.net/plugins/servlet/mobile?contentId=33948774#content/view/33948774
# The Data was collected at the RSNA 2017 annual meeting.
#
# 3. The data contains a list of all annotations on the images organized by arthor, disease type, location and patient, where the latter data are in the CSV file.
#
# 4. We can use Accuracy to evaluate the problem we are trying to solve here since precise prediction is the ultimate goal we now need the machine to help us.

# %% [markdown]
# ### * HW2

# %% [markdown]
# 1. The kernel problem here is how to increase profit, i.e. revenue minus cost.
# Suppose we have the data of numbers of people needed a drive in a certain place at a certain time, and we also have the route they are going to take. We can use these data to analyze how many cars and drivers we need and where they should find the most customers at a certain time. By these research and analyses, we can increase our profit in a scientific way.
#
# 2. How do we determine a person needed a drive?
# The most of time we needed a drive is to work, so we can look for working place data, and the distance from thier home to their working place.
# Next, we can check if a person have the habit of calling a taxi, or check if a person do not have any vehicles.
# These data may be available from our government.
#
# 3. The types of the collected dataset are numerical and categorical.
# The place can be a numerical data denoted by coordinates;
# the distance we need a drive is a numerical type data;
# the habit of taking a taxi appears to be a yes/no question, i.e. categorical data.
#
# 4. We can analyze our main problem by time we spent for waiting, how many customers a day, accuracy of the prediction we made based on the dataset.

# %% [markdown]
# ### HW3
# #### Please use a function to calculate Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y - yp)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 197.336
# The Mean absolute error is 11.391
