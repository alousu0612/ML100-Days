# %%
#import required libraries 
#import OpenCV library
import cv2
import numpy as np
#import matplotlib library
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# cv2.cvtColor is an OpenCV function to convert images to different color spaces
def convertToRGB(img): 
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
def detect_faces(filename, scale, neighbors, cascade_file='data/haarcascade_frontalface_alt.xml'):
    
    cascade = cv2.CascadeClassifier(cascade_file)
    image = cv2.imread('data/'+filename+'.jpg')
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    faces = cascade.detectMultiScale(gray, 
                                     scaleFactor=scale,
                                     minNeighbors=neighbors)
    
    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 1)
        
    return image, len(faces)

# %% [markdown]
# # 作業:
# 1. 使用faces = haar_face_cascade.detectMultiScale(gray_img, scaleFactor=1.1, minNeighbors=5);
# 修改 scaleFactor, minNeighbor兩個參數計算 test5.jpg 有幾張臉
#
# 2. load cascade classifier training file for haarcascade
# 3. load cascade classifier training file for lbpcascade

# %%
haar_face_cascade = 'data/haarcascade_frontalface_alt.xml'
lbp_cascade = 'data/lbpcascade_frontalcatface.xml'

# %%
plt.imshow(convertToRGB(cv2.imread('data/test5.jpg')))

# %%
for scl in range(11, 21):
    for neighbor in range(1, 11):
        img_detect_face, facenum = detect_faces('test5', scale=scl/10, neighbors=neighbor)
        print(f'{facenum} faces founded, with scaleFactor={scl/10}, and minNeighbors= {neighbor}')
# Out:
# 10 faces founded, with scaleFactor=1.1, and minNeighbors= 1
# 6 faces founded, with scaleFactor=1.1, and minNeighbors= 2
# 5 faces founded, with scaleFactor=1.1, and minNeighbors= 3
# 5 faces founded, with scaleFactor=1.1, and minNeighbors= 4
# 4 faces founded, with scaleFactor=1.1, and minNeighbors= 5
# 4 faces founded, with scaleFactor=1.1, and minNeighbors= 6
# 4 faces founded, with scaleFactor=1.1, and minNeighbors= 7
# 4 faces founded, with scaleFactor=1.1, and minNeighbors= 8
# 3 faces founded, with scaleFactor=1.1, and minNeighbors= 9
# 3 faces founded, with scaleFactor=1.1, and minNeighbors= 10
# 6 faces founded, with scaleFactor=1.2, and minNeighbors= 1
# 5 faces founded, with scaleFactor=1.2, and minNeighbors= 2
# 5 faces founded, with scaleFactor=1.2, and minNeighbors= 3
# 3 faces founded, with scaleFactor=1.2, and minNeighbors= 4
# 3 faces founded, with scaleFactor=1.2, and minNeighbors= 5
# 3 faces founded, with scaleFactor=1.2, and minNeighbors= 6
# ...

# %%
detect_img, nfaces = detect_faces('test5', scale=1.5, neighbors=1, cascade_file=haar_face_cascade)
plt.imshow(convertToRGB(detect_img))

# %%
for scl in range(11, 21):
    for neighbor in range(1, 7):
        img_detect_face, facenum = detect_faces('test5', scale=scl/10, neighbors=neighbor, cascade_file=lbp_cascade)
        print(f'{facenum} faces founded, with scaleFactor={scl/10}, and minNeighbors= {neighbor}')
# Out:
# 28 faces founded, with scaleFactor=1.1, and minNeighbors= 1
# 5 faces founded, with scaleFactor=1.1, and minNeighbors= 2
# 1 faces founded, with scaleFactor=1.1, and minNeighbors= 3
# 1 faces founded, with scaleFactor=1.1, and minNeighbors= 4
# 0 faces founded, with scaleFactor=1.1, and minNeighbors= 5
# 0 faces founded, with scaleFactor=1.1, and minNeighbors= 6
# 10 faces founded, with scaleFactor=1.2, and minNeighbors= 1
# 0 faces founded, with scaleFactor=1.2, and minNeighbors= 2
# 0 faces founded, with scaleFactor=1.2, and minNeighbors= 3
# 0 faces founded, with scaleFactor=1.2, and minNeighbors= 4
# 0 faces founded, with scaleFactor=1.2, and minNeighbors= 5
# 0 faces founded, with scaleFactor=1.2, and minNeighbors= 6
# 3 faces founded, with scaleFactor=1.3, and minNeighbors= 1
# 0 faces founded, with scaleFactor=1.3, and minNeighbors= 2
# 0 faces founded, with scaleFactor=1.3, and minNeighbors= 3
# 0 faces founded, with scaleFactor=1.3, and minNeighbors= 4
# ...

# %%
detect_img, nfaces = detect_faces('test5', scale=1.3, neighbors=1, cascade_file=lbp_cascade)
plt.imshow(convertToRGB(detect_img))
